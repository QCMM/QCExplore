# %%
# %%html
# <html>
# <div style="width:100%">
#   <div style="width:75%; float:left; background:white; margin:10px">
#     <img style ="width:100%"src ="https://raw.githubusercontent.com/publicunpublic/QCMM_Jupyter/main/full.svg">
#     <div style="margin-top:2.5%;position:absolute;background-color:#0e4be5;width:6%;height:0.3%"></div>
#   </div>
#
#   <div style="font-weight: bold;line-height: 1.4vw;font-family: sans-serif;font-size:1.3vw;width:10%; float:left; ; background:white; margin-left:0.7vw; margin-top:8vw;">
#     <a href="https://qcmm.udec.cl/" style="text-decoration: none;color:#0e4be5;"">QCMM Website</a><br>
#     <a href="https://github.com/QCMM"style="text-decoration: none;color:#0e4be5;">Github</a><br>
#     <a href="https://twitter.com/vohringerlab"style="text-decoration: none;color:#0e4be5;">Twitter</a><br>
#     <br>
#     2021
#   </div>
# </div>
# Out:
# <html>
# <div style="width:100%">
#   <div style="width:75%; float:left; background:white; margin:10px">
#     <img style ="width:100%"src ="https://raw.githubusercontent.com/publicunpublic/QCMM_Jupyter/main/full.svg">
#     <div style="margin-top:2.5%;position:absolute;background-color:#0e4be5;width:6%;height:0.3%"></div>
#   </div>
#
#   <div style="font-weight: bold;line-height: 1.4vw;font-family: sans-serif;font-size:1.3vw;width:10%; float:left; ; background:white; margin-left:0.7vw; margin-top:8vw;">
#     <a href="https://qcmm.udec.cl/" style="text-decoration: none;color:#0e4be5;"">QCMM Website</a><br>
#     <a href="https://github.com/QCMM"style="text-decoration: none;color:#0e4be5;">Github</a><br>
#     <a href="https://twitter.com/vohringerlab"style="text-decoration: none;color:#0e4be5;">Twitter</a><br>
#     <br>
#     2021
#   </div>
# </div>

# %%
# %%html
# <html>
# <center>
# <br>
# <h1 style="color:#0ee5a8;"> Create Reaction Stoichiometry for Reaction Path </h1>
# <br><br>
# </center>
# Out:
# <html>
# <center>
# <br>
# <h1 style="color:#0ee5a8;"> Create Reaction Stoichiometry for Reaction Path </h1>
# <br><br>
# </center>

# %%
import qcportal as ptl

# %% [markdown]
# ## Define Variables

# %%
client_address = "152.74.10.245:7778"
usrename = None
password = None
scan_collection_name = "salen_l-lac_i2--i3_02_b3lyp_def2-svp_35_42"
model_chem = "B3LYP-D3BJ/def2-tzvp-Psi4"

# %%
client = ptl.FractalClient(address=client_address, verify=False)

# %% [markdown]
# ##  A) List structures in the scan collection

# %%
ds  = client.get_collection("Dataset", scan_collection_name)
ds.get_entries()
# Out:
#     name molecule_id
# 0   3.69       23161
# 1   3.74       23104
# 2   3.34       23378
# 3   3.64       23198
# 4   3.19       23396
# 5   3.09       23402
# 6   3.04       23405
# 7   3.14       23398
# 8   3.29       23385
# 9   3.59       23204
# 10  3.54       23213
# 11  3.39       23374
# 12  1.94       23476
# 13  1.99       23474
# 14  2.09       23470
# 15  2.64       23432
# 16  3.24       23390
# 17  2.44       23450
# 18  1.89       23479
# 19  2.59       23438
# 20  2.84       23417
# 21  2.49       23447
# 22  2.69       23427
# 23  2.24       23463
# 24  1.79       23483
# 25  2.79       23420
# 26  2.04       23473
# 27  1.74       23485
# 28  2.99       23407
# 29  2.29       23459
# 30  3.49       23370
# 31  3.44       23372
# 32  2.94       23410
# 33  2.74       23423
# 34  2.89       23412
# 35  2.34       23457
# 36  2.54       23441
# 37  2.14       23468
# 38  1.84       23480
# 39  2.39       23455
# 40  2.19       23465

# %% [markdown]
# ##  B) Compute a different level of theory if necessary

# %%
c = ds.compute(method = 'pbe0-d3bj', basis = 'def2-tzvp', program = 'psi4', tag='rx_comp')
print(c)
# Out:
# ComputeResponse(nsubmitted=38 nexisting=0)

# %%
#c.dict()

# %% [markdown]
# ##  C)  Check the energies of the optimized points

# %%
import warnings
warnings.filterwarnings("ignore")

ds.get_values(program='psi4')
# Out:
#      PBE0/def2-tzvp-Psi4 B3LYP/def2-tzvp-Psi4 PBE0-D3BJ/def2-tzvp-Psi4  \
# 3.69      -1110046.28489      -1111223.044572          -1110093.378391
# 3.74     -1110046.346097      -1111223.146549          -1110093.378333
# 3.34     -1110045.346793      -1111221.612503          -1110093.181024
# 3.64      -1110046.67941      -1111223.057219          -1110094.249485
# 3.19     -1110043.440054      -1111219.392821          -1110092.188052
# 3.09     -1110042.088742      -1111217.800609          -1110091.140436
# 3.04     -1110041.330339      -1111216.933233          -1110090.514129
# 3.14     -1110042.805009      -1111218.638193           -1110091.70681
# 3.29     -1110044.912434      -1111221.083455          -1110093.028223
# 3.59     -1110046.638251      -1111222.986189          -1110094.222025
# 3.54     -1110046.766383       -1111223.25829          -1110094.275151
# 3.39     -1110045.769629      -1111222.116399          -1110093.521751
# 1.94     -1110026.236888      -1111200.544245          -1110076.880341
# 1.99      -1110027.60819      -1111201.898874          -1110078.172319
# 2.09     -1110029.658741      -1111203.994161          -1110080.074239
# 2.64     -1110036.034366      -1111211.344302          -1110085.772166
# 3.24     -1110044.253549       -1111220.32748          -1110092.593515
# 2.44     -1110033.845099      -1111208.742935          -1110083.692807
# 1.89     -1110024.422741      -1111198.889989          -1110075.135842
# 2.59     -1110035.775121      -1111211.015699          -1110085.433491
# 2.84     -1110037.815146       -1111213.12356          -1110087.484975
# 2.49     -1110034.712511      -1111209.804095          -1110084.329962
# 2.69     -1110035.551177      -1111210.666022          -1110085.484358
# 2.24     -1110031.620784      -1111206.080878          -1110081.917463
# 1.79     -1110024.583057      -1111203.486986          -1110073.981551
# 2.79     -1110036.956199      -1111212.192936          -1110086.731493
# 2.04     -1110028.747058      -1111203.045628          -1110079.227691
# 1.74     -1110023.817119      -1111202.963923          -1110073.077221
# 2.99     -1110040.561596       -1111216.08762          -1110089.852264
# 2.29     -1110031.973063        -1111206.5497          -1110082.009244
# 3.49     -1110046.457733      -1111222.911005          -1110094.059955
# 3.44     -1110046.131135      -1111222.540474          -1110093.810252
# 2.94     -1110039.537367      -1111214.997972          -1110088.974597
# 2.74     -1110036.225261      -1111211.412364          -1110086.077156
# 2.89     -1110038.659295      -1111214.024338           -1110088.23179
# 2.34     -1110032.511571      -1111207.151934          -1110082.508897
# 2.54     -1110035.019563      -1111210.133064          -1110084.766726
# 2.14     -1110030.406152       -1111204.73202          -1110080.815676
# 1.84     -1110024.289296      -1111202.569904          -1110074.185228
# 2.39     -1110033.182977      -1111207.941976          -1110083.107925
# 2.19     -1110031.039124      -1111205.388797          -1110081.416676
#
#      B3LYP-D3BJ/def2-tzvp-Psi4
# 3.69           -1111310.451364
# 3.74           -1111310.465873
# 3.34           -1111310.292519
# 3.64            -1111311.27776
# 3.19           -1111309.613071
# 3.09            -1111308.52933
# 3.04           -1111307.878074
# 3.14            -1111309.11645
# 3.29           -1111310.250856
# 3.59           -1111311.214473
# 3.54           -1111311.373214
# 3.39           -1111310.654321
# 1.94           -1111293.990873
# 1.99           -1111295.183008
# 2.09           -1111296.972515
# 2.64           -1111303.050802
# 3.24           -1111309.883035
# 2.44           -1111300.688648
# 1.89           -1111292.479971
# 2.59           -1111302.613451
# 2.84           -1111304.806446
# 2.49           -1111301.357884
# 2.69           -1111302.743054
# 2.24           -1111298.803272
# 1.79           -1111294.843172
# 2.79            -1111304.03853
# 2.04           -1111296.161476
# 1.74           -1111294.082703
# 2.99           -1111307.195175
# 2.29            -1111298.85527
# 3.49           -1111311.190205
# 3.44           -1111310.954413
# 2.94           -1111306.310465
# 2.74           -1111303.363925
# 2.89           -1111305.553096
# 2.34           -1111299.378483
# 2.54           -1111301.892532
# 2.14           -1111297.685412
# 1.84           -1111294.742656
# 2.39           -1111300.029794
# 2.19           -1111298.273941

# %% [markdown]
# ## D)  Plot the scan energy profile

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook


model_chem = model_chem

scan_df = ds.df
scan_df = scan_df[scan_df[model_chem].notnull()]

init_energy = scan_df[model_chem].sort_index().iloc[0]
scan_df['rel_scan_energy'] = scan_df[model_chem] - init_energy
energy = scan_df['rel_scan_energy']
rx_coord =  [float(x) for x in scan_df.index]

plt.scatter(rx_coord, energy)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## E) Save the scan profile in a molden file to visualize
#
# The file will appear in the folder where you run this notebook with name of the collection followed by
# an `_anim.dat` apendix

# %%
opt_mol_id = ds.get_entries().molecule_id
opt_mol = client.query_molecules(list(opt_mol_id))

xyz_str = ''
for m in opt_mol:
    xyz_str += m.to_string("xyz")

filename = ds.name+'_anim.dat'
with open(filename, 'w') as handle:
    handle.write(xyz_str)
